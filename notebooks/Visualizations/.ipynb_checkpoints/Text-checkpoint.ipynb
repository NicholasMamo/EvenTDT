# %% [markdown]
# # Text Visualizations
#
# Text visualizations can be used when the textual content needs to be highlighted. For example, a football match's participants can be displayed as a visualization to group them based on what they are - a team, a stadium, a coach or a player.

# %%
from matplotlib.lines import Line2D
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

import numpy as np
import os
import pandas as pd
import sys

# %% [markdown]
# The running example will be the line-ups of two football matches. They are text-intensive and difficul to represent otherwise. At the same time, a text visualization can add to the interpretability of simply writing out the line-ups, as shown further down.

# %%
"""
The first team - the home team.
"""

data = {
    'team':        [ 'Watford' ],
    'coach':       [ 'Quique Sánchez Flores' ],
    'stadium':     [ 'Vicarage Road' ],
    'player':      [ [ "Ben Foster", "Kiko Femenia", "Craig Dawson", "Christian Kabasele", "Jose Holebas", "Abdoulaye Doucoure", "Etienne Capoue", "Will Hughes", "Tom Cleverley", "Gerard Deulofeu", "Andre Gray" ] ],
    'substitute': [ [ "Heurelho Gomes", "Daryl Janmaat", "Adrian Mariappa", "Nathaniel Chalobah", "Ismaila Sarr", "Dimitri Foulquier", "Roberto Pereyra" ]  ]
}

home_df = pd.DataFrame.from_dict(data, orient='index').transpose()

"""
Convert the player list into multiple columns.
"""
player_df = home_df.player.apply(pd.Series)
player_df.columns = ['player'] * len(data['player'][0])
home_df.drop(['player'], axis=1, inplace=True) # drop the original player column

"""
Convert the substitute list into multiple columns.
"""
substitute_df = home_df.substitute.apply(pd.Series)
substitute_df.columns = ['substitute'] * len(data['substitute'][0])
home_df.drop(['substitute'], axis=1, inplace=True) # drop the original substitute column

"""
Merge the player and substitute list into the original dataframe.
"""
home_df = home_df.transpose()
home_df = pd.concat([ home_df, player_df.transpose() ])
home_df = pd.concat([ home_df, substitute_df.transpose() ])
home_df
# Out:
#                                 0
# team                      Watford
# coach       Quique Sánchez Flores
# stadium             Vicarage Road
# player                 Ben Foster
# player               Kiko Femenia
# player               Craig Dawson
# player         Christian Kabasele
# player               Jose Holebas
# player         Abdoulaye Doucoure
# player             Etienne Capoue
# player                Will Hughes
# player              Tom Cleverley
# player            Gerard Deulofeu
# player                 Andre Gray
# substitute         Heurelho Gomes
# substitute          Daryl Janmaat
# substitute        Adrian Mariappa
# substitute     Nathaniel Chalobah
# substitute           Ismaila Sarr
# substitute      Dimitri Foulquier
# substitute        Roberto Pereyra

# %%
"""
The second team - the away team.
"""

data = {
    'team':       [ 'Arsenal' ],
    'coach':      [ 'Unai Emery' ],
    'stadium':    [  ],
    'player':     [ [ "Bernd Leno", "Ainsley Maitland-Niles", "Sokratis", "David Luiz", "Sead Kolasinac", "Granit Xhaka", "Matteo Guendouzi", "Mesut Ozil", "Dani Ceballos", "Nicolas Pepe", "Pierre-Emerick Aubameyang" ] ],
    'substitute': [ [ "Lucas Torreira", "Calum Chambers", "Reiss Nelson", "Emiliano Martinez", "Joe Willock", "Gabriel Martinelli", "Bukayo Saka" ] ]
}

away_df = pd.DataFrame.from_dict(data, orient='index').transpose()

"""
Convert the player list into multiple columns.
"""
player_df = away_df.player.apply(pd.Series)
player_df.columns = ['player'] * len(data['player'][0])
away_df.drop(['player'], axis=1, inplace=True) # drop the original player column

"""
Convert the substitute list into multiple columns.
"""
substitute_df = away_df.substitute.apply(pd.Series)
substitute_df.columns = ['substitute'] * len(data['substitute'][0])
away_df.drop(['substitute'], axis=1, inplace=True) # drop the original substitute column

"""
Merge the player and substitute list into the original dataframe.
"""
away_df = away_df.transpose()
away_df = pd.concat([ away_df, player_df.transpose() ])
away_df = pd.concat([ away_df, substitute_df.transpose() ])
away_df
# Out:
#                                     0
# team                          Arsenal
# coach                      Unai Emery
# stadium                          None
# player                     Bernd Leno
# player         Ainsley Maitland-Niles
# player                       Sokratis
# player                     David Luiz
# player                 Sead Kolasinac
# player                   Granit Xhaka
# player               Matteo Guendouzi
# player                     Mesut Ozil
# player                  Dani Ceballos
# player                   Nicolas Pepe
# player      Pierre-Emerick Aubameyang
# substitute             Lucas Torreira
# substitute             Calum Chambers
# substitute               Reiss Nelson
# substitute          Emiliano Martinez
# substitute                Joe Willock
# substitute         Gabriel Martinelli
# substitute                Bukayo Saka

# %%
"""
The two dataframes are joined together.
The home and away dataframes make up a column each.
The participant type becomes the index.
"""

df = pd.concat([ home_df, away_df ], axis=1)
df.reset_index(inplace=True)
df.columns = [ 'participant', 'home', 'away' ]
df.set_index('participant', inplace=True)
df
# Out:
#                               home                       away
# participant
# team                       Watford                    Arsenal
# coach        Quique Sánchez Flores                 Unai Emery
# stadium              Vicarage Road                       None
# player                  Ben Foster                 Bernd Leno
# player                Kiko Femenia     Ainsley Maitland-Niles
# player                Craig Dawson                   Sokratis
# player          Christian Kabasele                 David Luiz
# player                Jose Holebas             Sead Kolasinac
# player          Abdoulaye Doucoure               Granit Xhaka
# player              Etienne Capoue           Matteo Guendouzi
# player                 Will Hughes                 Mesut Ozil
# player               Tom Cleverley              Dani Ceballos
# player             Gerard Deulofeu               Nicolas Pepe
# player                  Andre Gray  Pierre-Emerick Aubameyang
# substitute          Heurelho Gomes             Lucas Torreira
# substitute           Daryl Janmaat             Calum Chambers
# substitute         Adrian Mariappa               Reiss Nelson
# substitute      Nathaniel Chalobah          Emiliano Martinez
# substitute            Ismaila Sarr                Joe Willock
# substitute       Dimitri Foulquier         Gabriel Martinelli
# substitute         Roberto Pereyra                Bukayo Saka

# %% [markdown]
# In the visualization, special care is paid to ensuring that data is separated well using the proximity Gestalt principle. The different participant groups are separated by a wide white vertical space. The categories are separated by a wide vertical space.

# %%
plt.style.use(os.path.join(sys.path[0], "fire.style"))
plt.style.reload_library()

plt.figure(figsize=(10,10))

plt.xlim(0, 10)
plt.ylim(0, 10)

"""
Style.
"""
pad = 0.1 # the padding from the left border
row_height = 0.5 # the height of each row

"""
Each group is displayed separately.
"""
plt.gca().invert_yaxis() # invert the y-axis
rows = 0
for group in [ 'team', 'stadium', 'coach', 'player', 'substitute' ]:
    rows += 1 + (row_height if rows > 0 else 0)
    plt.text(pad, rows * row_height, group.capitalize(),
             fontweight=600, alpha=0.9)
    
    """
    Go through each row in the group.
    Then, for each category, print the name of the player.
    """
    categories = df.columns
    for i, (_, row) in enumerate(df.loc[[group]].iterrows()):
        rows += 1 if i else 0
        for index, category in enumerate(categories):
            plt.text(2 + index * 4, rows * row_height, row[category],
                     alpha=1, fontweight=600)

plt.axis('off')
plt.title('Line-ups', loc='left', fontweight='bold', alpha=0.9,
          pad=40) # pad to make space for a subtitle
ax = plt.gca()
plt.text(0, 1.02, 'The full line-up is shown below',
         fontsize='large', alpha=0.8,
         horizontalalignment='left', verticalalignment='bottom',
         transform=ax.transAxes)
plt.show()

# %% [markdown]
# This visualization does not tell a story on its own. However, it can be used similarly to a heatmap by assigning values to different participants. In this continuation of the above example, random values are assigned to the participants and used to create a heatmap textual visualization.

# %%
"""
Generate random values for the home team.
"""
values = np.random.normal(0.5, 0.5, len(home_df))
values = (values - min(values)) / (max(values) - min(values))
values = (values * 0.6) + 0.4

"""
Add them to a new dataframe.
"""
value_home_df = home_df.copy()
value_home_df.columns = [ 'name' ]
value_home_df['value'] = values
value_home_df
# Out:
#                              name     value
# team                      Watford  0.590674
# coach       Quique Sánchez Flores  0.666232
# stadium             Vicarage Road  0.656105
# player                 Ben Foster  0.745168
# player               Kiko Femenia  0.462534
# player               Craig Dawson  0.483977
# player         Christian Kabasele  0.667054
# player               Jose Holebas  0.474199
# player         Abdoulaye Doucoure  0.400000
# player             Etienne Capoue  0.612818
# player                Will Hughes  0.589026
# player              Tom Cleverley  0.687372
# player            Gerard Deulofeu  0.828463
# player                 Andre Gray  0.740879
# substitute         Heurelho Gomes  0.795457
# substitute          Daryl Janmaat  0.797401
# substitute        Adrian Mariappa  0.749411
# substitute     Nathaniel Chalobah  0.787183
# substitute           Ismaila Sarr  0.466071
# substitute      Dimitri Foulquier  0.558965
# substitute        Roberto Pereyra  1.000000

# %%
"""
Generate random values for the away team.
"""
values = np.random.normal(0.5, 0.5, len(away_df))
values = (values - min(values)) / (max(values) - min(values))
values = (values * 0.6) + 0.4

"""
Add them to a new dataframe.
"""
value_away_df = away_df.copy()
value_away_df.columns = [ 'name' ]
value_away_df['value'] = values
value_away_df
# Out:
#                                  name     value
# team                          Arsenal  0.700476
# coach                      Unai Emery  0.653204
# stadium                          None  0.882568
# player                     Bernd Leno  0.518402
# player         Ainsley Maitland-Niles  0.821001
# player                       Sokratis  0.731358
# player                     David Luiz  0.874566
# player                 Sead Kolasinac  0.875436
# player                   Granit Xhaka  0.613165
# player               Matteo Guendouzi  0.824787
# player                     Mesut Ozil  0.738415
# player                  Dani Ceballos  0.763197
# player                   Nicolas Pepe  0.749423
# player      Pierre-Emerick Aubameyang  0.557083
# substitute             Lucas Torreira  0.534260
# substitute             Calum Chambers  0.586843
# substitute               Reiss Nelson  1.000000
# substitute          Emiliano Martinez  0.581593
# substitute                Joe Willock  0.805545
# substitute         Gabriel Martinelli  0.608098
# substitute                Bukayo Saka  0.400000

# %%
"""
The two dataframes are joined together.
The home and away dataframes make up two columns each.
A multi-level index is created to separate them neatly.
The participant type becomes the index.
"""

df = pd.concat([ value_home_df, value_away_df ], axis=1)
df.reset_index(inplace=True)
columns = [ ('participant', 'participant'), ('home', 'name'), ('home', 'value'), ('away', 'name'), ('away', 'value') ]
df.columns = pd.MultiIndex.from_tuples(columns)
df.set_index(('participant','participant'), inplace=True)
df.index.name = 'participant'
df
# Out:
#                               home                                 away  \
#                               name     value                       name
# participant
# team                       Watford  0.590674                    Arsenal
# coach        Quique Sánchez Flores  0.666232                 Unai Emery
# stadium              Vicarage Road  0.656105                       None
# player                  Ben Foster  0.745168                 Bernd Leno
# player                Kiko Femenia  0.462534     Ainsley Maitland-Niles
# player                Craig Dawson  0.483977                   Sokratis
# player          Christian Kabasele  0.667054                 David Luiz
# player                Jose Holebas  0.474199             Sead Kolasinac
# player          Abdoulaye Doucoure  0.400000               Granit Xhaka
# player              Etienne Capoue  0.612818           Matteo Guendouzi
# player                 Will Hughes  0.589026                 Mesut Ozil
# player               Tom Cleverley  0.687372              Dani Ceballos
# player             Gerard Deulofeu  0.828463               Nicolas Pepe
# player                  Andre Gray  0.740879  Pierre-Emerick Aubameyang
# substitute          Heurelho Gomes  0.795457             Lucas Torreira
# substitute           Daryl Janmaat  0.797401             Calum Chambers
# substitute         Adrian Mariappa  0.749411               Reiss Nelson
# substitute      Nathaniel Chalobah  0.787183          Emiliano Martinez
# substitute            Ismaila Sarr  0.466071                Joe Willock
# substitute       Dimitri Foulquier  0.558965         Gabriel Martinelli
# substitute         Roberto Pereyra  1.000000                Bukayo Saka
#
#
#                 value
# participant
# team         0.700476
# coach        0.653204
# stadium      0.882568
# player       0.518402
# player       0.821001
# player       0.731358
# player       0.874566
# player       0.875436
# player       0.613165
# player       0.824787
# player       0.738415
# player       0.763197
# player       0.749423
# player       0.557083
# substitute   0.534260
# substitute   0.586843
# substitute   1.000000
# substitute   0.581593
# substitute   0.805545
# substitute   0.608098
# substitute   0.400000

# %% [markdown]
# In the heatmap, it is important that the labels remain readable. Therefore a minimum alpha has to be provided.

# %%
plt.style.use(os.path.join(sys.path[0], "fire.style"))
plt.style.reload_library()

plt.figure(figsize=(10,10))

plt.xlim(0, 10)
plt.ylim(0, 10)

"""
Style.
"""
pad = 0.1 # the padding from the left border
row_height = 0.5 # the height of each row

"""
Each group is displayed separately.
"""
plt.gca().invert_yaxis() # invert the y-axis
rows = 0
for group in [ 'team', 'stadium', 'coach', 'player', 'substitute' ]:
    rows += 1 + (row_height if rows > 0 else 0)
    plt.text(pad, rows * row_height, group.capitalize(),
             fontweight=600, alpha=0.8)
    
    """
    Go through each row in the group.
    Then, for each category, print the name of the player.
    """
    categories = {
        ('home', 'name'): ('home', 'value'),
        ('away', 'name'): ('away', 'value'),
    }
    for i, (_, row) in enumerate(df.loc[[group]].iterrows()):
        rows += 1 if i else 0
        for index, (category, value) in enumerate(categories.items()):
            plt.text(2 + index * 4, rows * row_height, row[category],
                     fontweight=600,
                     color='C3', alpha=row[value])

plt.axis('off')
plt.title('Line-ups', loc='left', fontweight='bold', alpha=0.9,
          pad=40) # pad to make space for a subtitle
ax = plt.gca()
plt.text(0, 1.02, 'The full line-up is shown below. The opacity represents the score of each participant.',
         fontsize='large', alpha=0.8,
         horizontalalignment='left', verticalalignment='bottom',
         transform=ax.transAxes)
plt.show()

# %% [markdown]
# A different kind of story can be provided by restricting the values to be between 0 and 1. In this scenario, the table could represent the players that were captured by the APD algorithm, for instance.
#
# In the following example, the home team is assumed to be the minority side - its participants have a lower chance of being picked.

# %%
"""
Generate random values for the home team.
"""
values = np.random.choice( [ 0, 0, 0, 1 ], len(home_df))

"""
Add them to a new dataframe.
"""
boolean_home_df = home_df.copy()
boolean_home_df.columns = [ 'name' ]
boolean_home_df['value'] = values
boolean_home_df
# Out:
#                              name  value
# team                      Watford      0
# coach       Quique Sánchez Flores      1
# stadium             Vicarage Road      1
# player                 Ben Foster      0
# player               Kiko Femenia      0
# player               Craig Dawson      0
# player         Christian Kabasele      0
# player               Jose Holebas      0
# player         Abdoulaye Doucoure      0
# player             Etienne Capoue      0
# player                Will Hughes      0
# player              Tom Cleverley      0
# player            Gerard Deulofeu      0
# player                 Andre Gray      0
# substitute         Heurelho Gomes      1
# substitute          Daryl Janmaat      0
# substitute        Adrian Mariappa      0
# substitute     Nathaniel Chalobah      0
# substitute           Ismaila Sarr      0
# substitute      Dimitri Foulquier      0
# substitute        Roberto Pereyra      1

# %%
"""
Generate random values for the away team.
"""
values = np.random.choice( [ 0, 1, 1, 1 ], len(home_df))

"""
Add them to a new dataframe.
"""
boolean_away_df = away_df.copy()
boolean_away_df.columns = [ 'name' ]
boolean_away_df['value'] = values
boolean_away_df
# Out:
#                                  name  value
# team                          Arsenal      1
# coach                      Unai Emery      1
# stadium                          None      1
# player                     Bernd Leno      0
# player         Ainsley Maitland-Niles      0
# player                       Sokratis      0
# player                     David Luiz      1
# player                 Sead Kolasinac      1
# player                   Granit Xhaka      1
# player               Matteo Guendouzi      0
# player                     Mesut Ozil      0
# player                  Dani Ceballos      1
# player                   Nicolas Pepe      1
# player      Pierre-Emerick Aubameyang      0
# substitute             Lucas Torreira      1
# substitute             Calum Chambers      1
# substitute               Reiss Nelson      1
# substitute          Emiliano Martinez      1
# substitute                Joe Willock      1
# substitute         Gabriel Martinelli      1
# substitute                Bukayo Saka      1

# %%
"""
The two dataframes are joined together.
The home and away dataframes make up two columns each.
A multi-level index is created to separate them neatly.
The participant type becomes the index.
"""

df = pd.concat([ boolean_home_df, boolean_away_df ], axis=1)
df.reset_index(inplace=True)
columns = [ ('participant', 'participant'), ('home', 'name'), ('home', 'value'), ('away', 'name'), ('away', 'value') ]
df.columns = pd.MultiIndex.from_tuples(columns)
df.set_index(('participant','participant'), inplace=True)
df.index.name = 'participant'
df
# Out:
#                               home                             away
#                               name value                       name value
# participant
# team                       Watford     0                    Arsenal     1
# coach        Quique Sánchez Flores     1                 Unai Emery     1
# stadium              Vicarage Road     1                       None     1
# player                  Ben Foster     0                 Bernd Leno     0
# player                Kiko Femenia     0     Ainsley Maitland-Niles     0
# player                Craig Dawson     0                   Sokratis     0
# player          Christian Kabasele     0                 David Luiz     1
# player                Jose Holebas     0             Sead Kolasinac     1
# player          Abdoulaye Doucoure     0               Granit Xhaka     1
# player              Etienne Capoue     0           Matteo Guendouzi     0
# player                 Will Hughes     0                 Mesut Ozil     0
# player               Tom Cleverley     0              Dani Ceballos     1
# player             Gerard Deulofeu     0               Nicolas Pepe     1
# player                  Andre Gray     0  Pierre-Emerick Aubameyang     0
# substitute          Heurelho Gomes     1             Lucas Torreira     1
# substitute           Daryl Janmaat     0             Calum Chambers     1
# substitute         Adrian Mariappa     0               Reiss Nelson     1
# substitute      Nathaniel Chalobah     0          Emiliano Martinez     1
# substitute            Ismaila Sarr     0                Joe Willock     1
# substitute       Dimitri Foulquier     0         Gabriel Martinelli     1
# substitute         Roberto Pereyra     1                Bukayo Saka     1

# %% [markdown]
# In this case, the difference between the participants does not have to be as pronounced as in the heatmap. Therefore the alpha values can be closer to each other - 0.5-1, not 0.25-1. That way, readability is maintained while the message still comes across. It is still amply clear that most of the away team's players were picked, and that few of the home team's players were picked.

# %%
plt.style.use(os.path.join(sys.path[0], "fire.style"))
plt.style.reload_library()

plt.figure(figsize=(10,10))

plt.xlim(0, 10)
plt.ylim(0, 10)

"""
Style.
"""
pad = 0.1 # the padding from the left border
row_height = 0.5 # the height of each row

"""
Each group is displayed separately.
"""
plt.gca().invert_yaxis() # invert the y-axis
rows = 0
for group in [ 'team', 'stadium', 'coach', 'player', 'substitute' ]:
    rows += 1 + (row_height if rows > 0 else 0)
    plt.text(pad, rows * row_height, group.capitalize(),
             fontweight=600, alpha=0.9)
    
    """
    Go through each row in the group.
    Then, for each category, print the name of the player.
    """
    categories = {
        ('home', 'name'): ('home', 'value'),
        ('away', 'name'): ('away', 'value'),
    }
    for i, (_, row) in enumerate(df.loc[[group]].iterrows()):
        rows += 1 if i else 0
        for index, (category, value) in enumerate(categories.items()):
            plt.text(2 + index * 4, rows * row_height, row[category],
                     fontweight=600,
                     color='C3', alpha=max(row[value], 0.5))

plt.axis('off')
plt.title('Line-ups', loc='left', fontweight='bold', alpha=0.9,
          pad=40) # pad to make space for a subtitle
ax = plt.gca()
plt.text(0, 1.02, 'The full line-up is shown below. Opaque participants were captured.',
         fontsize='large', alpha=0.8,
         horizontalalignment='left', verticalalignment='bottom',
         transform=ax.transAxes)
plt.show()

# %% [markdown]
# ## Annotations
#
# Textual visualizations can also be useful when text needs to be annotated. For example, in Natural Language Processing (NER), many tasks annotate the text for various applications.
#
# In the next example, a simple sentence is tokenized and its named entities are annotated.

# %%
import nltk

sentence = "Anthony Lopes is a Portuguese professional footballer who plays for \
Olympique Lyonnais as a goalkeeper."

tokens = nltk.word_tokenize(sentence)
pos_tags = nltk.pos_tag(tokens)
entities = [ entity 
            for entity in nltk.ne_chunk(pos_tags, binary=True) ] # we are not interested in the type of named entity

"""
Collect the named entities.
"""
named_entities = []
for entity in entities:
    if type(entity) == nltk.tree.Tree:
        named_entity_tokens = [ pair[0] for pair in entity ]
        named_entities.append(named_entity_tokens)

named_entities
# Out:
# [['Anthony', 'Lopes'], ['Portuguese'], ['Olympique', 'Lyonnais']]

# %%
plt.style.use(os.path.join(sys.path[0], "fire.style"))
plt.style.reload_library()

figure = plt.figure(figsize=(5,2))
renderer = figure.canvas.get_renderer()

plt.xlim(0, 0.5)

"""
Style.
"""
word_pad = 0.01 # the padding between words (in pixels)

plt.gca().invert_yaxis() # invert the y-axis
offset = 0
for token in tokens:
    text = plt.text(offset, 0.5, token)
    
    """
    Subsequent text components will be offset.
    """
    bb = text.get_window_extent(renderer).inverse_transformed(plt.gca().transData)
    offset = offset + bb.width + word_pad
    
    """
    Annotate named entities.
    """
    if any(token in named_entity for named_entity in named_entities):
        print(token)

plt.axis('off')
plt.title('Named Entities', loc='left', fontweight='bold', alpha=0.9,
          pad=40) # pad to make space for a subtitle
ax = plt.gca()
plt.text(0, 1.02, 'The named entities that were extracted from the phrase.',
         fontsize='large', alpha=0.8,
         horizontalalignment='left', verticalalignment='bottom',
         transform=ax.transAxes)
plt.show()
# Out:
# Anthony
# Lopes
# Portuguese
# Olympique
# Lyonnais
